# %% [markdown]
# # Python for Data Science course: PART 2
# <img src="images/pandas.jpg" width="300">
#
# Pandas (the name is derived from the term "panel data") is a software library written for the Python programming language for data manipulation and analysis. In particular, it offers data structures and operations for manipulating numerical tables and time series. It is free software released under the three-clause BSD license.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Python-for-Data-Science-course:-PART-2" data-toc-modified-id="Python-for-Data-Science-course:-PART-2-0"><span class="toc-item-num">0&nbsp;&nbsp;</span>Python for Data Science course: PART 2</a></span></li><li><span><a href="#Pandas" data-toc-modified-id="Pandas-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Pandas<a class="anchor" id="pandas"></a></a></span><ul class="toc-item"><li><span><a href="#Create-DataFrame" data-toc-modified-id="Create-DataFrame-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Create DataFrame<a class="anchor" id="dataframe"></a></a></span><ul class="toc-item"><li><span><a href="#Dataframe-index" data-toc-modified-id="Dataframe-index-1.1.1"><span class="toc-item-num">1.1.1&nbsp;&nbsp;</span>Dataframe index<a class="anchor" id="index"></a></a></span></li><li><span><a href="#Save/load-dataframe-info-to-csv" data-toc-modified-id="Save/load-dataframe-info-to-csv-1.1.2"><span class="toc-item-num">1.1.2&nbsp;&nbsp;</span>Save/load dataframe info to csv<a class="anchor" id="save"></a></a></span><ul class="toc-item"><li><span><a href="#Save-dataframe-to-csv" data-toc-modified-id="Save-dataframe-to-csv-1.1.2.1"><span class="toc-item-num">1.1.2.1&nbsp;&nbsp;</span>Save dataframe to csv</a></span></li><li><span><a href="#Load-dataframe-from-csv" data-toc-modified-id="Load-dataframe-from-csv-1.1.2.2"><span class="toc-item-num">1.1.2.2&nbsp;&nbsp;</span>Load dataframe from csv</a></span></li><li><span><a href="#Load-a-dataset-from-seaborn" data-toc-modified-id="Load-a-dataset-from-seaborn-1.1.2.3"><span class="toc-item-num">1.1.2.3&nbsp;&nbsp;</span>Load a dataset from seaborn<a class="anchor" id="load"></a></a></span></li></ul></li><li><span><a href="#Basic-Instructions" data-toc-modified-id="Basic-Instructions-1.1.3"><span class="toc-item-num">1.1.3&nbsp;&nbsp;</span>Basic Instructions<a class="anchor" id="basics"></a></a></span></li><li><span><a href="#Access-to-data" data-toc-modified-id="Access-to-data-1.1.4"><span class="toc-item-num">1.1.4&nbsp;&nbsp;</span>Access to data<a class="anchor" id="access"></a></a></span></li><li><span><a href="#What-would-happend-if-we-use-the-loc-with-the-data-frame-with-categorical-index?" data-toc-modified-id="What-would-happend-if-we-use-the-loc-with-the-data-frame-with-categorical-index?-1.1.5"><span class="toc-item-num">1.1.5&nbsp;&nbsp;</span>What would happend if we use the loc with the data frame with categorical index?</a></span></li><li><span><a href="#Groupby" data-toc-modified-id="Groupby-1.1.6"><span class="toc-item-num">1.1.6&nbsp;&nbsp;</span>Groupby<a class="anchor" id="groupby"></a></a></span></li></ul></li></ul></li><li><span><a href="#Exercise" data-toc-modified-id="Exercise-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Exercise<a class="anchor" id="exercise"></a></a></span><ul class="toc-item"><li><span><a href="#Read-CSV" data-toc-modified-id="Read-CSV-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Read CSV</a></span></li><li><span><a href="#Show-the-columns-and-if-there-is-a-categorical-or-numerical-index." data-toc-modified-id="Show-the-columns-and-if-there-is-a-categorical-or-numerical-index.-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Show the columns and if there is a categorical or numerical index.</a></span></li><li><span><a href="#Show-the-description-of-the-columns,-how-many-columns-are-categorical?-and-numerical?" data-toc-modified-id="Show-the-description-of-the-columns,-how-many-columns-are-categorical?-and-numerical?-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Show the description of the columns, how many columns are categorical? and numerical?</a></span></li><li><span><a href="#How-many-Teams-are-in-the-dataset?-Which-are-the-names-of-each-team?" data-toc-modified-id="How-many-Teams-are-in-the-dataset?-Which-are-the-names-of-each-team?-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>How many Teams are in the dataset? Which are the names of each team?</a></span></li><li><span><a href="#Who-is-the-most-paid-player?-And-which-is-his-team?" data-toc-modified-id="Who-is-the-most-paid-player?-And-which-is-his-team?-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Who is the most paid player? And which is his team?</a></span><ul class="toc-item"><li><span><a href="#Using-loc" data-toc-modified-id="Using-loc-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Using loc</a></span></li><li><span><a href="#Using-iloc" data-toc-modified-id="Using-iloc-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Using iloc</a></span></li></ul></li><li><span><a href="#Which-is-the-mean-Salary-of-each-Team?-Which-are-the-5-highest-mean-salaries?" data-toc-modified-id="Which-is-the-mean-Salary-of-each-Team?-Which-are-the-5-highest-mean-salaries?-2.6"><span class="toc-item-num">2.6&nbsp;&nbsp;</span>Which is the mean Salary of each Team? Which are the 5 highest mean salaries?</a></span></li></ul></li></ul></div>

# %%
# Dependencies

#!conda install -c conda-forge seaborn -y
#!conda install -c conda-forge pandas -y

# %%
import pandas as pd
import seaborn as sns

# %% [markdown]
# # Pandas<a class="anchor" id="pandas"></a>

# %%
data = {"name": ["Sophia", "John", "Jennifer", "Edgar", "Patrick"],
       "gender": ["F", "M", "F", "M", "M"],
       "country": ["Bulgaria", "USA", "USA", "England", "Netherlands"],
       "age": [23, 24, 46, 13, 72]}

# %% [markdown]
# ## Create DataFrame<a class="anchor" id="dataframe"></a>

# %%
df = pd.DataFrame(data)
df
# Out:
#        name gender      country  age
# 0    Sophia      F     Bulgaria   23
# 1      John      M          USA   24
# 2  Jennifer      F          USA   46
# 3     Edgar      M      England   13
# 4   Patrick      M  Netherlands   72

# %%
df.columns
# Out:
# Index(['name', 'gender', 'country', 'age'], dtype='object')

# %% [markdown]
# ### Dataframe index<a class="anchor" id="index"></a>

# %%
# Show index
df.index
# Out:
# RangeIndex(start=0, stop=5, step=1)

# %%
# Set index to column: name
df.set_index('name', drop=True, inplace=True)

# %%
df
# Out:
#          gender      country  age
# name
# Sophia        F     Bulgaria   23
# John          M          USA   24
# Jennifer      F          USA   46
# Edgar         M      England   13
# Patrick       M  Netherlands   72

# %%
df.reset_index(inplace=False, drop=False)
# Out:
#        name gender      country  age
# 0    Sophia      F     Bulgaria   23
# 1      John      M          USA   24
# 2  Jennifer      F          USA   46
# 3     Edgar      M      England   13
# 4   Patrick      M  Netherlands   72

# %% [markdown]
# ### Save/load dataframe info to csv<a class="anchor" id="save"></a>

# %% [markdown]
# #### Save dataframe to csv

# %%
# Save dataframe to CSV
df.to_csv('small_data.csv', index=False)

# %% [markdown]
# #### Load dataframe from csv

# %%
pd.read_csv('small_data.csv')
# Out:
#   gender      country  age
# 0      F     Bulgaria   23
# 1      M          USA   24
# 2      F          USA   46
# 3      M      England   13
# 4      M  Netherlands   72

# %% [markdown]
# #### Load a dataset from seaborn<a class="anchor" id="load"></a>

# %%
df = sns.load_dataset('tips')
df_index = sns.load_dataset('tips')
df_index.set_index('sex', drop=True, inplace=True)

# %% [markdown]
# ### Basic Instructions<a class="anchor" id="basics"></a>

# %%
# Show the first 5 rows of the dataset
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
df_index.head()
# Out:
#         total_bill   tip smoker  day    time  size
# sex
# Female       16.99  1.01     No  Sun  Dinner     2
# Male         10.34  1.66     No  Sun  Dinner     3
# Male         21.01  3.50     No  Sun  Dinner     3
# Male         23.68  3.31     No  Sun  Dinner     2
# Female       24.59  3.61     No  Sun  Dinner     4

# %%
# Show the information of the dataframe columns
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
# total_bill    244 non-null float64
# tip           244 non-null float64
# sex           244 non-null category
# smoker        244 non-null category
# day           244 non-null category
# time          244 non-null category
# size          244 non-null int64
# dtypes: category(4), float64(2), int64(1)
# memory usage: 7.3 KB

# %%
# Shows the stadistical data of the numerical attributes
df.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
# Shows the description of the categorical attributes
df.describe(include='category')
# Out:
#          sex smoker  day    time
# count    244    244  244     244
# unique     2      2    4       2
# top     Male     No  Sat  Dinner
# freq     157    151   87     176

# %%
# Show the unique values of a column
df.sex.unique()
# Out:
# [Female, Male]
# Categories (2, object): [Female, Male]

# %%
# Show the count of the unique values of a column
df.sex.nunique()
# Out:
# 2

# %%
df[['tip']].head()
# Out:
#     tip
# 0  1.01
# 1  1.66
# 2  3.50
# 3  3.31
# 4  3.61

# %%
df.tip.head()
# Out:
# 0    1.01
# 1    1.66
# 2    3.50
# 3    3.31
# 4    3.61
# Name: tip, dtype: float64

# %%
df[['tip', 'sex']].head()
# Out:
#     tip     sex
# 0  1.01  Female
# 1  1.66    Male
# 2  3.50    Male
# 3  3.31    Male
# 4  3.61  Female

# %% [markdown]
# ### Access to data<a class="anchor" id="access"></a>

# %%
# Acess by the rows index
df[2:4]
# Out:
#    total_bill   tip   sex smoker  day    time  size
# 2       21.01  3.50  Male     No  Sun  Dinner     3
# 3       23.68  3.31  Male     No  Sun  Dinner     2

# %%
# Purely integer-location based indexing for selection by position.
df[df.iloc[:]['tip'] > 5]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 44        30.40   5.60    Male     No   Sun  Dinner     4
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 52        34.81   5.20  Female     No   Sun  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 85        34.83   5.17  Female     No  Thur   Lunch     4
# 88        24.71   5.85    Male     No  Thur   Lunch     2
# 116       29.93   5.07    Male     No   Sun  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 155       29.85   5.14  Female     No   Sun  Dinner     5
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 181       23.33   5.65    Male    Yes   Sun  Dinner     2
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 211       25.89   5.16    Male    Yes   Sat  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 239       29.03   5.92    Male     No   Sat  Dinner     3

# %%
#Access a group of rows and columns by label(s) or a boolean array.
df.loc[239]
# Out:
# total_bill     29.03
# tip             5.92
# sex             Male
# smoker            No
# day              Sat
# time          Dinner
# size               3
# Name: 239, dtype: object

# %% [markdown]
# ### What would happend if we use the loc with the data frame with categorical index?

# %%
df_index.loc[239]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-fc6dcada7a0c> in <module>
# ----> 1 df_index.loc[239]
#
# ~\AppData\Local\Continuum\anaconda3\envs\course\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1422
#    1423             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1424             return self._getitem_axis(maybe_callable, axis=axis)
#    1425
#    1426     def _is_scalar_access(self, key: Tuple):
#
# ~\AppData\Local\Continuum\anaconda3\envs\course\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1847
#    1848         # fall thru to straight lookup
# -> 1849         self._validate_key(key, axis)
#    1850         return self._get_label(key, axis=axis)
#    1851
#
# ~\AppData\Local\Continuum\anaconda3\envs\course\lib\site-packages\pandas\core\indexing.py in _validate_key(self, key, axis)
#    1723
#    1724         if not is_list_like_indexer(key):
# -> 1725             self._convert_scalar_indexer(key, axis)
#    1726
#    1727     def _is_scalar_access(self, key: Tuple):
#
# ~\AppData\Local\Continuum\anaconda3\envs\course\lib\site-packages\pandas\core\indexing.py in _convert_scalar_indexer(self, key, axis)
#     272         ax = self.obj._get_axis(min(axis, self.ndim - 1))
#     273         # a scalar
# --> 274         return ax._convert_scalar_indexer(key, kind=self.name)
#     275
#     276     def _convert_slice_indexer(self, key, axis: int):
#
# ~\AppData\Local\Continuum\anaconda3\envs\course\lib\site-packages\pandas\core\indexes\category.py in _convert_scalar_indexer(self, key, kind)
#     717             return self.categories._convert_scalar_indexer(key, kind=kind)
#     718
# --> 719         return super()._convert_scalar_indexer(key, kind=kind)
#     720
#     721     @Appender(_index_shared_docs["_convert_list_indexer"])
#
# ~\AppData\Local\Continuum\anaconda3\envs\course\lib\site-packages\pandas\core\indexes\base.py in _convert_scalar_indexer(self, key, kind)
#    3136             elif kind in ["loc"] and is_integer(key):
#    3137                 if not self.holds_integer():
# -> 3138                     return self._invalid_indexer("label", key)
#    3139
#    3140         return key
#
# ~\AppData\Local\Continuum\anaconda3\envs\course\lib\site-packages\pandas\core\indexes\base.py in _invalid_indexer(self, form, key)
#    3338             "cannot do {form} indexing on {klass} with these "
#    3339             "indexers [{key}] of {kind}".format(
# -> 3340                 form=form, klass=type(self), key=key, kind=type(key)
#    3341             )
#    3342         )
#
# TypeError: cannot do label indexing on <class 'pandas.core.indexes.category.CategoricalIndex'> with these indexers [239] of <class 'int'>

# %%
try:
    df_index.loc[239]
except Exception as e:
    print(str(e))

# %% [markdown]
# As the index is categorical we cannot search in the dataframe by a numerical index.

# %%
df_index.index.categories
# Out:
# Index(['Male', 'Female'], dtype='object')

# %%
df_index.loc['Male']
# Out:
#       total_bill   tip smoker  day    time  size
# sex
# Male       10.34  1.66     No  Sun  Dinner     3
# Male       21.01  3.50     No  Sun  Dinner     3
# Male       23.68  3.31     No  Sun  Dinner     2
# Male       25.29  4.71     No  Sun  Dinner     4
# Male        8.77  2.00     No  Sun  Dinner     2
# ...          ...   ...    ...  ...     ...   ...
# Male       12.60  1.00    Yes  Sat  Dinner     2
# Male       32.83  1.17    Yes  Sat  Dinner     2
# Male       29.03  5.92     No  Sat  Dinner     3
# Male       22.67  2.00    Yes  Sat  Dinner     2
# Male       17.82  1.75     No  Sat  Dinner     2
#
# [157 rows x 6 columns]

# %%
#df.loc[2:5]
df[df.loc[:, 'tip'] > 5]
# Out:
#      total_bill    tip     sex smoker   day    time  size
# 23        39.42   7.58    Male     No   Sat  Dinner     4
# 44        30.40   5.60    Male     No   Sun  Dinner     4
# 47        32.40   6.00    Male     No   Sun  Dinner     4
# 52        34.81   5.20  Female     No   Sun  Dinner     4
# 59        48.27   6.73    Male     No   Sat  Dinner     4
# 85        34.83   5.17  Female     No  Thur   Lunch     4
# 88        24.71   5.85    Male     No  Thur   Lunch     2
# 116       29.93   5.07    Male     No   Sun  Dinner     4
# 141       34.30   6.70    Male     No  Thur   Lunch     6
# 155       29.85   5.14  Female     No   Sun  Dinner     5
# 170       50.81  10.00    Male    Yes   Sat  Dinner     3
# 172        7.25   5.15    Male    Yes   Sun  Dinner     2
# 181       23.33   5.65    Male    Yes   Sun  Dinner     2
# 183       23.17   6.50    Male    Yes   Sun  Dinner     4
# 211       25.89   5.16    Male    Yes   Sat  Dinner     4
# 212       48.33   9.00    Male     No   Sat  Dinner     4
# 214       28.17   6.50  Female    Yes   Sat  Dinner     3
# 239       29.03   5.92    Male     No   Sat  Dinner     3

# %% [markdown]
# ### Groupby<a class="anchor" id="groupby"></a>

# %%
df.groupby('sex')['total_bill'].describe()
# Out:
#         count       mean       std   min    25%    50%    75%    max
# sex
# Male    157.0  20.744076  9.246469  7.25  14.00  18.35  24.71  50.81
# Female   87.0  18.056897  8.009209  3.07  12.75  16.40  21.52  44.30

# %% [markdown]
# # Exercise<a class="anchor" id="exercise"></a>

# %% [markdown]
# In this exercise we are going to use a csv with the information of the nba players and their salary. You can download the file in the next [link](https://media.geeksforgeeks.org/wp-content/uploads/nba-2.csv).
#
# Once downloaded follow the next steps:
# * Read the csv
# * Show the columns and if there is a categorical or numerical index.
# * Show the description of the columns, how many columns are categorical? and numerical?
# * How many Teams are in the dataset? Which are the names of each team?
# * Who is the most paid player? And which is his team?
# * Which is the mean Salary of each Team? Which are the 5 highest mean salaries?

# %% [markdown]
# ## Read CSV

# %%
data = pd.read_csv("nba.csv", index_col ="Name")

# %% [markdown]
# ## Show the columns and if there is a categorical or numerical index.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 458 entries, Avery Bradley to nan
# Data columns (total 8 columns):
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(4)
# memory usage: 32.2+ KB

# %%
data.columns
# Out:
# Index(['Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College',
#        'Salary'],
#       dtype='object')

# %%
data.index
# Out:
# Index([ 'Avery Bradley',    'Jae Crowder',   'John Holland',    'R.J. Hunter',
#         'Jonas Jerebko',   'Amir Johnson',  'Jordan Mickey',   'Kelly Olynyk',
#          'Terry Rozier',   'Marcus Smart',
#        ...
#        'Gordon Hayward',    'Rodney Hood',     'Joe Ingles',  'Chris Johnson',
#            'Trey Lyles',   'Shelvin Mack',      'Raul Neto',   'Tibor Pleiss',
#           'Jeff Withey',              nan],
#       dtype='object', name='Name', length=458)

# %%
data.index.name
# Out:
# 'Name'

# %% [markdown]
# There are 8 columns: 'Team', 'Number', 'Position', 'Age', 'Height', 'Weight', 'College', 'Salary'
# There is a categorical index called Name and contains all the names of the players.

# %% [markdown]
# ## Show the description of the columns, how many columns are categorical? and numerical?

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 458 entries, Avery Bradley to nan
# Data columns (total 8 columns):
# Team        457 non-null object
# Number      457 non-null float64
# Position    457 non-null object
# Age         457 non-null float64
# Height      457 non-null object
# Weight      457 non-null float64
# College     373 non-null object
# Salary      446 non-null float64
# dtypes: float64(4), object(4)
# memory usage: 32.2+ KB

# %%
data.describe()
# Out:
#            Number         Age      Weight        Salary
# count  457.000000  457.000000  457.000000  4.460000e+02
# mean    17.678337   26.938731  221.522976  4.842684e+06
# std     15.966090    4.404016   26.368343  5.229238e+06
# min      0.000000   19.000000  161.000000  3.088800e+04
# 25%      5.000000   24.000000  200.000000  1.044792e+06
# 50%     13.000000   26.000000  220.000000  2.839073e+06
# 75%     25.000000   30.000000  240.000000  6.500000e+06
# max     99.000000   40.000000  307.000000  2.500000e+07

# %%
data.describe(include='object')
# Out:
#                         Team Position Height   College
# count                    457      457    457       373
# unique                    30        5     18       118
# top     New Orleans Pelicans       SG    6-9  Kentucky
# freq                      19      102     59        22

# %%
data.describe(include='all')
# Out:
#                         Team      Number Position         Age Height  \
# count                    457  457.000000      457  457.000000    457
# unique                    30         NaN        5         NaN     18
# top     New Orleans Pelicans         NaN       SG         NaN    6-9
# freq                      19         NaN      102         NaN     59
# mean                     NaN   17.678337      NaN   26.938731    NaN
# std                      NaN   15.966090      NaN    4.404016    NaN
# min                      NaN    0.000000      NaN   19.000000    NaN
# 25%                      NaN    5.000000      NaN   24.000000    NaN
# 50%                      NaN   13.000000      NaN   26.000000    NaN
# 75%                      NaN   25.000000      NaN   30.000000    NaN
# max                      NaN   99.000000      NaN   40.000000    NaN
#
#             Weight   College        Salary
# count   457.000000       373  4.460000e+02
# unique         NaN       118           NaN
# top            NaN  Kentucky           NaN
# freq           NaN        22           NaN
# mean    221.522976       NaN  4.842684e+06
# std      26.368343       NaN  5.229238e+06
# min     161.000000       NaN  3.088800e+04
# 25%     200.000000       NaN  1.044792e+06
# 50%     220.000000       NaN  2.839073e+06
# 75%     240.000000       NaN  6.500000e+06
# max     307.000000       NaN  2.500000e+07

# %% [markdown]
# There are 4 numerical columns(Number, Age, Weight, Salary) and other 4 categorical (Team, Position, Height, College)

# %% [markdown]
# ## How many Teams are in the dataset? Which are the names of each team?

# %%
len(data.Team.unique())
# Out:
# 31

# %%
data.Team.nunique()
# Out:
# 30

# %%
data.Team.unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz',
#        nan], dtype=object)

# %%
data.Team.nunique(dropna=False)
# Out:
# 31

# %%
data['Team'].unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz',
#        nan], dtype=object)

# %%
pd.DataFrame(data['Team'].unique(), columns=['teams'])
# Out:
#                      teams
# 0           Boston Celtics
# 1            Brooklyn Nets
# 2          New York Knicks
# 3       Philadelphia 76ers
# 4          Toronto Raptors
# 5    Golden State Warriors
# 6     Los Angeles Clippers
# 7       Los Angeles Lakers
# 8             Phoenix Suns
# 9         Sacramento Kings
# 10           Chicago Bulls
# 11     Cleveland Cavaliers
# 12         Detroit Pistons
# 13          Indiana Pacers
# 14         Milwaukee Bucks
# 15        Dallas Mavericks
# 16         Houston Rockets
# 17       Memphis Grizzlies
# 18    New Orleans Pelicans
# 19       San Antonio Spurs
# 20           Atlanta Hawks
# 21       Charlotte Hornets
# 22              Miami Heat
# 23           Orlando Magic
# 24      Washington Wizards
# 25          Denver Nuggets
# 26  Minnesota Timberwolves
# 27   Oklahoma City Thunder
# 28  Portland Trail Blazers
# 29               Utah Jazz
# 30                     NaN

# %%
pd.DataFrame(data.groupby('Team').groups.keys(), columns=['teams'])
# Out:
#                      teams
# 0            Atlanta Hawks
# 1           Boston Celtics
# 2            Brooklyn Nets
# 3        Charlotte Hornets
# 4            Chicago Bulls
# 5      Cleveland Cavaliers
# 6         Dallas Mavericks
# 7           Denver Nuggets
# 8          Detroit Pistons
# 9    Golden State Warriors
# 10         Houston Rockets
# 11          Indiana Pacers
# 12    Los Angeles Clippers
# 13      Los Angeles Lakers
# 14       Memphis Grizzlies
# 15              Miami Heat
# 16         Milwaukee Bucks
# 17  Minnesota Timberwolves
# 18    New Orleans Pelicans
# 19         New York Knicks
# 20   Oklahoma City Thunder
# 21           Orlando Magic
# 22      Philadelphia 76ers
# 23            Phoenix Suns
# 24  Portland Trail Blazers
# 25        Sacramento Kings
# 26       San Antonio Spurs
# 27         Toronto Raptors
# 28               Utah Jazz
# 29      Washington Wizards

# %% [markdown]
# ##  Who is the most paid player? And which is his team?

# %%
data[['Salary','Team']]
# Out:
#                   Salary            Team
# Name
# Avery Bradley  7730337.0  Boston Celtics
# Jae Crowder    6796117.0  Boston Celtics
# John Holland         NaN  Boston Celtics
# R.J. Hunter    1148640.0  Boston Celtics
# Jonas Jerebko  5000000.0  Boston Celtics
# ...                  ...             ...
# Shelvin Mack   2433333.0       Utah Jazz
# Raul Neto       900000.0       Utah Jazz
# Tibor Pleiss   2900000.0       Utah Jazz
# Jeff Withey     947276.0       Utah Jazz
# NaN                  NaN             NaN
#
# [458 rows x 2 columns]

# %% [markdown]
# ### Using loc

# %%
data[data.loc[:, 'Salary'] == max(data.Salary)]
# Out:
#                            Team  Number Position   Age Height  Weight College  \
# Name
# Kobe Bryant  Los Angeles Lakers    24.0       SF  37.0    6-6   212.0     NaN
#
#                  Salary
# Name
# Kobe Bryant  25000000.0

# %%
data[data.loc[:, 'Salary'] == max(data.Salary)].index[0]
# Out:
# 'Kobe Bryant'

# %%
data[data.loc[:, 'Salary'] == max(data.Salary)].Team
# Out:
# Name
# Kobe Bryant    Los Angeles Lakers
# Name: Team, dtype: object

# %% [markdown]
# ### Using iloc

# %%
data[data.iloc[:]['Salary'] == max(data.Salary)]
# Out:
#                            Team  Number Position   Age Height  Weight College  \
# Name
# Kobe Bryant  Los Angeles Lakers    24.0       SF  37.0    6-6   212.0     NaN
#
#                  Salary
# Name
# Kobe Bryant  25000000.0

# %%
data[data[:]['Salary'] == max(data.Salary)]
# Out:
#                            Team  Number Position   Age Height  Weight College  \
# Name
# Kobe Bryant  Los Angeles Lakers    24.0       SF  37.0    6-6   212.0     NaN
#
#                  Salary
# Name
# Kobe Bryant  25000000.0

# %% [markdown]
# ## Which is the mean Salary of each Team? Which are the 5 highest mean salaries?

# %%
data.groupby('Team')['Salary'].describe()['mean']
# Out:
# Team
# Atlanta Hawks             4.860197e+06
# Boston Celtics            4.181505e+06
# Brooklyn Nets             3.501898e+06
# Charlotte Hornets         5.222728e+06
# Chicago Bulls             5.785559e+06
# Cleveland Cavaliers       7.642049e+06
# Dallas Mavericks          4.746582e+06
# Denver Nuggets            4.294424e+06
# Detroit Pistons           4.477884e+06
# Golden State Warriors     5.924600e+06
# Houston Rockets           5.018868e+06
# Indiana Pacers            4.450122e+06
# Los Angeles Clippers      6.323643e+06
# Los Angeles Lakers        4.784695e+06
# Memphis Grizzlies         5.467920e+06
# Miami Heat                6.347359e+06
# Milwaukee Bucks           4.350220e+06
# Minnesota Timberwolves    4.593054e+06
# New Orleans Pelicans      4.355304e+06
# New York Knicks           4.581494e+06
# Oklahoma City Thunder     6.251020e+06
# Orlando Magic             4.297248e+06
# Philadelphia 76ers        2.213778e+06
# Phoenix Suns              4.229676e+06
# Portland Trail Blazers    3.220121e+06
# Sacramento Kings          4.778911e+06
# San Antonio Spurs         5.629516e+06
# Toronto Raptors           4.741174e+06
# Utah Jazz                 4.204006e+06
# Washington Wizards        5.088576e+06
# Name: mean, dtype: float64

# %%
meanSalaries = pd.DataFrame(data.groupby('Team')['Salary'].describe()['mean'])

# %%
meanSalaries
# Out:
#                                 mean
# Team
# Atlanta Hawks           4.860197e+06
# Boston Celtics          4.181505e+06
# Brooklyn Nets           3.501898e+06
# Charlotte Hornets       5.222728e+06
# Chicago Bulls           5.785559e+06
# Cleveland Cavaliers     7.642049e+06
# Dallas Mavericks        4.746582e+06
# Denver Nuggets          4.294424e+06
# Detroit Pistons         4.477884e+06
# Golden State Warriors   5.924600e+06
# Houston Rockets         5.018868e+06
# Indiana Pacers          4.450122e+06
# Los Angeles Clippers    6.323643e+06
# Los Angeles Lakers      4.784695e+06
# Memphis Grizzlies       5.467920e+06
# Miami Heat              6.347359e+06
# Milwaukee Bucks         4.350220e+06
# Minnesota Timberwolves  4.593054e+06
# New Orleans Pelicans    4.355304e+06
# New York Knicks         4.581494e+06
# Oklahoma City Thunder   6.251020e+06
# Orlando Magic           4.297248e+06
# Philadelphia 76ers      2.213778e+06
# Phoenix Suns            4.229676e+06
# Portland Trail Blazers  3.220121e+06
# Sacramento Kings        4.778911e+06
# San Antonio Spurs       5.629516e+06
# Toronto Raptors         4.741174e+06
# Utah Jazz               4.204006e+06
# Washington Wizards      5.088576e+06

# %%
meanSalaries.sort_values('mean', ascending=False).head(10)
# Out:
#                                mean
# Team
# Cleveland Cavaliers    7.642049e+06
# Miami Heat             6.347359e+06
# Los Angeles Clippers   6.323643e+06
# Oklahoma City Thunder  6.251020e+06
# Golden State Warriors  5.924600e+06
# Chicago Bulls          5.785559e+06
# San Antonio Spurs      5.629516e+06
# Memphis Grizzlies      5.467920e+06
# Charlotte Hornets      5.222728e+06
# Washington Wizards     5.088576e+06
